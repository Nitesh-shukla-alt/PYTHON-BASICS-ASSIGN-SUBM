# %%
"""Q1-What is Python, and why is it popular 

ANS
Python is a high-level, general-purpose programming language known for its clear syntax and readability
    and following reasons are also very important
Ease of Learning: Python reads almost like plain English, which makes it perfect for beginners.

Versatile Applications: It’s used for web development, data analysis, machine learning, automation, app development, and more.

Massive Community: Tons of support, tutorials, and libraries from millions of Pythonistas worldwide.

Rich Libraries: Frameworks like Django (for web), Pandas (for data), and TensorFlow (for AI) speed up development.

Cross-Platform: Write your code once and run it on Windows, Mac, or Linux.


Q2. What is an Interpreter in Python?
Python uses an interpreter, which reads and executes code line by line.

It converts Python code into machine instructions during runtime.

Great for debugging because it runs immediately and shows errors on the spot.



Q3. What are Pre-defined Keywords in Python?
Keywords are reserved words that Python uses to define syntax and structure.

Examples include: if, else, elif, for, while, True, False, None, def, class.

Q4. Can Keywords Be Used as Variable Names?
Nope! You cannot use keywords as variable names.

Doing so causes a SyntaxError. For example, if = 5 is invalid.

Q5. What is Mutability in Python?
Mutability refers to whether an object can be changed after it's created.

Mutable objects can be modified (e.g., lists).

Immutable objects cannot be modified (e.g., strings, tuples).

Q6. Why Are Lists Mutable, But Tuples Are Immutable?
Lists: Built to be flexible—elements can be added, changed, or removed.

Tuples: Designed for integrity—once created, their contents are fixed.

This distinction allows tuples to be used as keys in dictionaries, unlike lists.

Q7. What Is the Difference Between “==” and “is” Operators?
Operator	Meaning	Example
==	Checks if values are equal	a == b → True if values match
is	Checks if objects are identical	a is b → True if same memory

Q8. What Are Logical Operators in Python?
They’re used to combine conditional statements:

and: True if both conditions are True.

or: True if at least one condition is True.

not: Reverses the result (True → False, False → True).

Q9. What Is Type Casting in Python?
It means converting one data type into another.

For example: int("5") → converts string "5" to integer 5.

Q10. Difference Between Implicit and Explicit Type Casting
Type	Description	Example
Implicit	Python automatically converts types	3 + 2.0 → 5.0
Explicit	Programmer manually converts types using functions	float(3) → 3.0

Q11. What Is the Purpose of Conditional Statements?
They guide the flow of your program based on conditions.

Allow decision-making using if, elif, else.

Q12. How Does the elif Statement Work?
Stands for "else if".

Used when you want multiple conditions:"""

PYTHON CODE

if score > 90:
    print("Excellent")
elif score > 75:
    print("Good")
else:
    print("Try again")

"""Q13. Difference Between for and while Loops
Loop Type	Best For	Condition
for	Iterating over sequences	Known iteration count
while	Based on a condition	Unknown iteration count



Q14. Scenario Where a while Loop Is More Suitable
Example: Asking for user input until they enter a valid password."""

PYTHON CODE

password = ""
while password != "OpenSesame":
    password = input("Enter the password: ")




#PYTHON PRACTICAL QUESTIONS

#️Q1 Print "Hello, World!"
#python
# Print a basic message
print("Hello, World!")


️#Q2 Display Your Name and Age
#python
# Define variables and display them
name = "Your Name"
age = 25
print("Name:", name)
print("Age:", age)

#Q3 Show All Python Keywords
#python
# Use the keyword module to list reserved keywords
import keyword
print(keyword.kwlist)

#Q4 Check if a Word Is a Keyword
#python
import keyword

# Take user input and verify if it's a keyword
word = input("Enter a word: ")
if keyword.iskeyword(word):
    print(f"{word} is a Python keyword.")
else:
    print(f"{word} is not a Python keyword.")

    
#️Q5 Mutable vs Immutable Arguments
#python
def test_mutability(a_list, a_tuple):
    a_list[0] = "changed"  # Lists are mutable
    try:
        a_tuple[0] = "changed"  # Tuples are immutable
    except TypeError:
        print("Tuples are immutable.")

lst = [1, 2, 3]
tpl = (1, 2, 3)
test_mutability(lst, tpl)
print("List after function:", lst)
print("Tuple after function:", tpl)


️#Q6 Basic Arithmetic on User Inputs
#python
# Read two numbers and perform operations
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))

print("Sum:", a + b)
print("Difference:", a - b)
print("Product:", a * b)
print("Division:", a / b)


️#Q7 Logical Operators Demo
#python
x = True
y = False

print("x and y:", x and y)
print("x or y:", x or y)
print("not x:", not x)

#Q8️ List vs Tuple Mutability
#python
my_list = [1, 2, 3]
my_tuple = (1, 2, 3)

# Change list element
my_list[0] = 100
print("Modified list:", my_list)

# Attempt to change tuple element
try:
    my_tuple[0] = 100
except TypeError:
    print("Cannot modify tuple elements.")

    
#Q9 Convert Input to Different Types
#python
value = input("Enter something: ")

int_val = int(value)
float_val = float(value)
bool_val = bool(value)

print("Integer:", int_val)
print("Float:", float_val)
print("Boolean:", bool_val)


#Q10 Type Casting List Elements
#python
str_list = ['1', '2', '3']
int_list = [int(i) for i in str_list]
print(int_list)


#Q11 Check Number Sign
#python
num = float(input("Enter a number: "))
if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")

    
#Q12 For Loop: Print 1 to 10
#python
for i in range(1, 11):
    print(i)

    
#Q13 Sum of Even Numbers (1–50)
#python
total = 0
for i in range(2, 51, 2):
    total += i
print("Sum of even numbers:", total)

#Q14 Reverse String Using While Loop
#python
s = input("Enter a string: ")
reversed_str = ""
i = len(s) - 1
while i >= 0:
    reversed_str += s[i]
    i -= 1
print("Reversed string:", reversed_str)


#Q15 Factorial Using While Loop
#python
num = int(input("Enter a number: "))
fact = 1
while num > 0:
    fact *= num
    num -= 1
print("Factorial:", fact)
